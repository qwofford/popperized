# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('troubleshooting1.csv',header=None)

# %%
sleeps = df[[10,11]]
sleeps = sleeps.rename(columns={10:'expected_sleep',11:'actual_sleep'})

# %%
sleeps.plot()

# %%
sleeps.head()
# Out:
#    expected_sleep  actual_sleep
# 0           59016         59148
# 1           60214         60264
# 2           60708         60761
# 3           59771         59826
# 4           59027         59078

# %%
plt.plot((sleeps['expected_sleep']-sleeps['actual_sleep']))

# %% [markdown]
# # Does longer sleep make it worse?

# %%
df = pd.read_csv('troubleshooting_long1.csv',header=None)

# %%
sleeps = df[[10,11]]
sleeps = sleeps.rename(columns={10:'expected_sleep',11:'actual_sleep'})

# %%
sleeps.plot()

# %%
sleeps.head()
# Out:
#    expected_sleep  actual_sleep
# 0          299016        299131
# 1          300214        300274
# 2          300708        301030
# 3          299771        299834
# 4          299027        299088

# %%
plt.plot((sleeps['expected_sleep']-sleeps['actual_sleep']))

# %%
df = pd.read_csv('troubleshooting_superlong.csv',header=None)

# %%
sleeps = df[[10,11]]
sleeps = sleeps.rename(columns={10:'expected_sleep',11:'actual_sleep'})

# %%
sleeps.plot()

# %%
sleeps.head()
# Out:
#    expected_sleep  actual_sleep
# 0         2999016       3058714
# 1         3000214       3055385
# 2         3000708       3055047
# 3         2999771       3058258
# 4         2999027       3045482

# %%
plt.plot((sleeps['expected_sleep']-sleeps['actual_sleep']))

# %% [markdown]
# # Let's get rid of the usecond wait and use our rdtsc

# %%
df = pd.read_csv('troubleshooting_superlongrdtsc.csv',header=None)

# %%
sleeps = df[[10,11]]
sleeps = sleeps.rename(columns={10:'expected_sleep',11:'actual_sleep'})

# %%
sleeps.plot()

# %%
sleeps.head()
# Out:
#    expected_sleep  actual_sleep
# 0         2999016       2999441
# 1         3000214       3000665
# 2         3000708       3001219
# 3         2999771       3000110
# 4         2999027       2999391

# %%
plt.plot((sleeps['expected_sleep']-sleeps['actual_sleep']))
